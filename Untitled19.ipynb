# %% [markdown]
# <a href="https://colab.research.google.com/github/manshacirrus/Object-detection/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycocotools>=2.0.1

# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip
# !rm annotations_trainval2017.zip
# !mkdir COCOdataset2017
# !mv annotations COCOdataset2017/
# Out:
# --2024-03-19 10:31:18--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.27.20, 52.216.39.81, 3.5.1.162, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.27.20|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  46.4MB/s    in 5.7s
#
# 2024-03-19 10:31:23 (42.4 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
#
# Archive:  annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
from pycocotools.coco import COCO
from tqdm import tqdm_notebook
import urllib.request
import os, cv2
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
coco = COCO('COCOdataset2017/annotations/instances_train2017.json')
# Out:
# loading annotations into memory...
# Done (t=15.83s)
# creating index...
# index created!

# %%
cats = coco.loadCats(coco.getCatIds())

# Print categories
nms=[cat['name'] for cat in cats]
print(f"{len(cats)} categories: \n{', '.join(nms)}")
# Out:
# 80 categories:
# person, bicycle, car, motorcycle, airplane, bus, train, truck, boat, traffic light, fire hydrant, stop sign, parking meter, bench, bird, cat, dog, horse, sheep, cow, elephant, bear, zebra, giraffe, backpack, umbrella, handbag, tie, suitcase, frisbee, skis, snowboard, sports ball, kite, baseball bat, baseball glove, skateboard, surfboard, tennis racket, bottle, wine glass, cup, fork, knife, spoon, bowl, banana, apple, sandwich, orange, broccoli, carrot, hot dog, pizza, donut, cake, chair, couch, potted plant, bed, dining table, toilet, tv, laptop, mouse, remote, keyboard, cell phone, microwave, oven, toaster, sink, refrigerator, book, clock, vase, scissors, teddy bear, hair drier, toothbrush

# %%
catIds = coco.getCatIds(catNms=['person', 'car', 'bicycle'])

# Get images ids
imgIds = coco.getImgIds(catIds=catIds)

# Load images
images = coco.loadImgs(imgIds)

print(len(imgIds))
print("imgIds: ", imgIds[0])
print("images: ", images[0])
# Out:
# 1101
# imgIds:  247808
# images:  {'license': 3, 'file_name': '000000247808.jpg', 'coco_url': 'http://images.cocodataset.org/train2017/000000247808.jpg', 'height': 640, 'width': 378, 'date_captured': '2013-11-23 05:08:51', 'flickr_url': 'http://farm1.staticflickr.com/199/485431395_f55e8bb06d_z.jpg', 'id': 247808}

# %%
import os
import urllib.request
from tqdm.notebook import tqdm_notebook

im_folder = 'COCOdataset2017/images/train/'

# Create directory if it doesn't exist
os.makedirs(im_folder, exist_ok=True)

# Download images
for im in tqdm_notebook(images):
    im_path = os.path.join(im_folder, im['file_name'])  # Use os.path.join for joining paths
    if not os.path.exists(im_path):
        urllib.request.urlretrieve(im['coco_url'], im_path)
# Out:
#   0%|          | 0/1101 [00:00<?, ?it/s]

# %%
img = images[np.random.randint(0, len(imgIds))]
im = cv2.imread(im_folder + img['file_name'])
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im), plt.axis('off');

# %%
# Example of manually creating a list of annotations
annotations = [
    {"id": 1, "category_id": 1, "bbox": [10, 20, 100, 150]},
    {"id": 2, "category_id": 2, "bbox": [50, 60, 200, 250]},
    # Add more annotations as needed
]

# %%
[{nms[annot['category_id'] - 1]: annot['bbox']} for annot in annotations]
# Out:
# [{'person': [10, 20, 100, 150]}, {'bicycle': [50, 60, 200, 250]}]

# %%
annotations[0]
# Out:
# {'id': 1, 'category_id': 1, 'bbox': [10, 20, 100, 150]}

# %%
# !pip install --upgrade mxnet-cu100 gluoncv
# Out:
# Collecting mxnet-cu100
#   Downloading mxnet_cu100-1.9.0-py3-none-manylinux2014_x86_64.whl (354.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.0/354.0 MB 2.8 MB/s eta 0:00:00
# Collecting gluoncv
#   Downloading gluoncv-0.10.5.post0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.10/dist-packages (from mxnet-cu100) (1.25.2)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from mxnet-cu100) (2.31.0)
# Collecting graphviz<0.9.0,>=0.8.1 (from mxnet-cu100)
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gluoncv) (4.66.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gluoncv) (3.7.1)
# Collecting portalocker (from gluoncv)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from gluoncv) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gluoncv) (1.11.4)
# Collecting yacs (from gluoncv)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from gluoncv) (1.5.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from gluoncv) (6.0.1)
# Collecting autocfg (from gluoncv)
#   Downloading autocfg-0.0.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from gluoncv) (4.8.0.76)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet-cu100) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet-cu100) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet-cu100) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet-cu100) (2024.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gluoncv) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gluoncv) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->gluoncv) (1.16.0)
# Installing collected packages: yacs, portalocker, graphviz, autocfg, mxnet-cu100, gluoncv
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.1
#     Uninstalling graphviz-0.20.1:
#       Successfully uninstalled graphviz-0.20.1
# Successfully installed autocfg-0.0.8 gluoncv-0.10.5.post0 graphviz-0.8.4 mxnet-cu100-1.9.0 portalocker-2.8.2 yacs-0.1.8

# %%
# !wget https://gluon-cv.mxnet.io/_downloads/b6ade342998e03f5eaa0f129ad5eee80/mscoco.py
# !python mscoco.py --download-dir ./coco
# Out:
# --2024-03-19 10:40:54--  https://gluon-cv.mxnet.io/_downloads/b6ade342998e03f5eaa0f129ad5eee80/mscoco.py
# Resolving gluon-cv.mxnet.io (gluon-cv.mxnet.io)... 142.251.2.121, 2607:f8b0:4023:c0d::79
# Connecting to gluon-cv.mxnet.io (gluon-cv.mxnet.io)|142.251.2.121|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cv.gluon.ai/_downloads/b6ade342998e03f5eaa0f129ad5eee80/mscoco.py [following]
# --2024-03-19 10:40:54--  https://cv.gluon.ai/_downloads/b6ade342998e03f5eaa0f129ad5eee80/mscoco.py
# Resolving cv.gluon.ai (cv.gluon.ai)... 18.154.206.65, 18.154.206.11, 18.154.206.3, ...
# Connecting to cv.gluon.ai (cv.gluon.ai)|18.154.206.65|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-03-19 10:40:54 ERROR 403: Forbidden.
#
# python3: can't open file '/content/mscoco.py': [Errno 2] No such file or directory

# %%
id_ = np.random.randint(0, 117266)
train_image, train_label = train_dataset[id_]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (x_min, y_min, x_max, y_max):\n', bounding_boxes)
print('Class IDs:\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.axis('off'), plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6f1d1d5d08b3> in <cell line: 2>()
#       1 id_ = np.random.randint(0, 117266)
# ----> 2 train_image, train_label = train_dataset[id_]
#       3 bounding_boxes = train_label[:, :4]
#       4 class_ids = train_label[:, 4:5]
#       5 print('Image size (height, width, RGB):', train_image.shape)
#
# NameError: name 'train_dataset' is not defined

# %%
from gluoncv import data, utils

train_dataset = data.COCODetection(root='./coco', splits=['instances_train2017'])
val_dataset = data.COCODetection(root='./coco', splits=['instances_val2017'])
print('Num of training images:', len(train_dataset))
print('Num of validation images:', len(val_dataset))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-8ec909e46a10> in <cell line: 1>()
# ----> 1 from gluoncv import data, utils
#       2
#       3 train_dataset = data.COCODetection(root='./coco', splits=['instances_train2017'])
#       4 val_dataset = data.COCODetection(root='./coco', splits=['instances_val2017'])
#       5 print('Num of training images:', len(train_dataset))
#
# /usr/local/lib/python3.10/dist-packages/gluoncv/__init__.py in <module>
#      14 _found_mxnet = _found_pytorch = False
#      15 try:
# ---> 16     _require_mxnet_version('1.4.0', '2.0.0')
#      17     from . import data
#      18     from . import model_zoo
#
# /usr/local/lib/python3.10/dist-packages/gluoncv/check.py in _require_mxnet_version(mx_version, max_mx_version)
#       4 def _require_mxnet_version(mx_version, max_mx_version='2.0.0'):
#       5     try:
# ----> 6         import mxnet as mx
#       7         from distutils.version import LooseVersion
#       8         if LooseVersion(mx.__version__) < LooseVersion(mx_version) or \
#
# /usr/local/lib/python3.10/dist-packages/mxnet/__init__.py in <module>
#      21 """MXNet: a concise, fast and flexible framework for deep learning."""
#      22
# ---> 23 from .context import Context, current_context, cpu, gpu, cpu_pinned
#      24 from . import engine, error
#      25 from .base import MXNetError
#
# /usr/local/lib/python3.10/dist-packages/mxnet/context.py in <module>
#      21 import warnings
#      22 import ctypes
# ---> 23 from .base import classproperty, with_metaclass, _MXClassPropertyMetaClass
#      24 from .base import _LIB
#      25 from .base import check_call
#
# /usr/local/lib/python3.10/dist-packages/mxnet/base.py in <module>
#     354 __version__ = libinfo.__version__
#     355 # library instance of mxnet
# --> 356 _LIB = _load_lib()
#     357
#     358 # type definitions
#
# /usr/local/lib/python3.10/dist-packages/mxnet/base.py in _load_lib()
#     345         lib = ctypes.CDLL(lib_path[0], winmode=0x00000008)
#     346     else:
# --> 347         lib = ctypes.CDLL(lib_path[0], ctypes.RTLD_LOCAL)
#     348     # DMatrix functions
#     349     lib.MXGetLastError.restype = ctypes.c_char_p
#
# /usr/lib/python3.10/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     372
#     373         if handle is None:
# --> 374             self._handle = _dlopen(self._name, mode)
#     375         else:
#     376             self._handle = handle
#
# OSError: libcudnn.so.7: cannot open shared object file: No such file or directory

# %%
import os
import urllib.request
from tqdm.notebook import tqdm_notebook
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
from torchvision import transforms, datasets, models
import torch
import torch.nn as nn
import torch.optim as optim

# Define paths and download COCO dataset
# !pip install pycocotools>=2.0.1
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip
# !rm annotations_trainval2017.zip
# !mkdir COCOdataset2017
# !mv annotations COCOdataset2017/

# Load COCO annotations
coco = COCO('COCOdataset2017/annotations/instances_train2017.json')

# Get category names
cats = coco.loadCats(coco.getCatIds())
nms = [cat['name'] for cat in cats]

# Define image folder and download images
im_folder = 'COCOdataset2017/images/train/'
os.makedirs(im_folder, exist_ok=True)

imgIds = coco.getImgIds()
images = coco.loadImgs(imgIds)

for im in tqdm_notebook(images):
    im_path = os.path.join(im_folder, im['file_name'])
    if not os.path.exists(im_path):
        urllib.request.urlretrieve(im['coco_url'], im_path)

# Define transforms for image preprocessing
data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Define model
model = models.resnet50(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(nms))  # Change the output layer to match the number of classes

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Train the model (if needed)

# Save the model (if needed)

# Perform object detection on the images (using the trained model if available)
# Out:
# --2024-03-25 07:50:03--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.29.45, 52.217.82.196, 52.216.54.9, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.29.45|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  78.1MB/s    in 3.4s
#
# 2024-03-25 07:50:06 (71.0 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
#
# Archive:  annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json
# loading annotations into memory...
# Done (t=21.39s)
# creating index...
# index created!
#   0%|          | 0/118287 [00:00<?, ?it/s]
